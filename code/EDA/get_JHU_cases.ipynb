# %%
import pandas as pd
import c3aidatalake

# %%
def get_JHU(state):
    today = pd.Timestamp.now().strftime("%Y-%m-%d")
    rst = c3aidatalake.evalmetrics(
        "outbreaklocation",
        {
            "spec" : {
                "filter": "contains(id, '{}')".format(state),
                #"filter": """contains(id, 'Georgia') || contains(id, 'Florida') 
                #            || contains(id, 'California') || contains(id, 'NewYork')""",
                "expressions" : ['JHU_ConfirmedCases', 'JHU_ConfirmedDeaths', 'JHU_ConfirmedRecoveries'],
                "start" : '2020-01-01',
                "end" : today,
                "interval" : "DAY",
            }
        }
    )
    rst['dates'] = rst['dates'].astype(str)
    out = rst.T.reset_index()
    out.columns = out.iloc[0]
    out = out.iloc[1:]
    #out.insert(0, 'measure', out['dates'].apply(lambda x: x.split('UnitedStates.')[1]+'.'+x.split('UnitedStates.')[2]))
    out.insert(0, 'measure', out['dates'].apply(lambda x: 'JHU' + x.split('JHU')[1]))
    #out.insert(0, 'state', state)
    out.drop(['dates'], axis=1, inplace=True)
    #out = out.groupby(['state', 'measure']).sum().reset_index()
    out = out.groupby(['measure']).sum().reset_index()
    out['measure'] = out.apply(lambda row: state + '.' + row['measure'], axis=1)
    ts = out.T
    ts.columns = ts.iloc[0]
    ts = ts[1:].reset_index()
    ts.rename({0:'date'}, axis=1,inplace=True)
    return ts
    #return out

# %%
ga = get_JHU('Georgia')
ga
# Out:
# measure        date Georgia.JHU_ConfirmedCases.data  \
# 0        2020-01-01                               0
# 1        2020-01-02                               0
# 2        2020-01-03                               0
# 3        2020-01-04                               0
# 4        2020-01-05                               0
# ..              ...                             ...
# 297      2020-10-24                          725918
# 298      2020-10-25                          729599
# 299      2020-10-26                          732438
# 300      2020-10-27                          734647
# 301      2020-10-28                          734652
#
# measure Georgia.JHU_ConfirmedCases.missing Georgia.JHU_ConfirmedDeaths.data  \
# 0                                     1900                                0
# 1                                     1900                                0
# 2                                     1900                                0
# 3                                     1900                                0
# 4                                     1900                                0
# ..                                     ...                              ...
# 297                                    500                            15888
# 298                                    500                            15898
# 299                                    500                            15931
# 300                                    500                            15959
# 301                                    500                            15959
#
# measure Georgia.JHU_ConfirmedDeaths.missing  \
# 0                                      1900
# 1                                      1900
# 2                                      1900
# 3                                      1900
# 4                                      1900
# ..                                      ...
# 297                                     500
# 298                                     500
# 299                                     500
# 300                                     500
# 301                                     500
#
# measure Georgia.JHU_ConfirmedRecoveries.data  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ..                                       ...
# 297                                        0
# 298                                        0
# 299                                        0
# 300                                        0
# 301                                        0
#
# measure Georgia.JHU_ConfirmedRecoveries.missing
# 0                                         18100
# 1                                         18100
# 2                                         18100
# 3                                         18100
# 4                                         18100
# ..                                          ...
# 297                                       18100
# 298                                       18100
# 299                                       18100
# 300                                       18100
# 301                                       18100
#
# [302 rows x 7 columns]

# %%
ca = get_JHU('California')
ca
# Out:
# measure        date California.JHU_ConfirmedCases.data  \
# 0        2020-01-01                                  0
# 1        2020-01-02                                  0
# 2        2020-01-03                                  0
# 3        2020-01-04                                  0
# 4        2020-01-05                                  0
# ..              ...                                ...
# 297      2020-10-24                        1.84955e+06
# 298      2020-10-25                        1.85302e+06
# 299      2020-10-26                        1.86271e+06
# 300      2020-10-27                        1.86978e+06
# 301      2020-10-28                        1.87026e+06
#
# measure California.JHU_ConfirmedCases.missing  \
# 0                                        5700
# 1                                        5700
# 2                                        5700
# 3                                        5700
# 4                                        5700
# ..                                        ...
# 297                                      4200
# 298                                      4200
# 299                                      4200
# 300                                      4200
# 301                                      4200
#
# measure California.JHU_ConfirmedDeaths.data  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
# ..                                      ...
# 297                                   41115
# 298                                   41133
# 299                                   41206
# 300                                   41314
# 301                                   41315
#
# measure California.JHU_ConfirmedDeaths.missing  \
# 0                                         5700
# 1                                         5700
# 2                                         5700
# 3                                         5700
# 4                                         5700
# ..                                         ...
# 297                                       4200
# 298                                       4200
# 299                                       4200
# 300                                       4200
# 301                                       4200
#
# measure California.JHU_ConfirmedRecoveries.data  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 297                                           0
# 298                                           0
# 299                                           0
# 300                                           0
# 301                                           0
#
# measure California.JHU_ConfirmedRecoveries.missing
# 0                                            11500
# 1                                            11500
# 2                                            11500
# 3                                            11500
# 4                                            11500
# ..                                             ...
# 297                                          11500
# 298                                          11500
# 299                                          11500
# 300                                          11500
# 301                                          11500
#
# [302 rows x 7 columns]

# %%
fl = get_JHU('Florida')
fl
# Out:
# measure        date Florida.JHU_ConfirmedCases.data  \
# 0        2020-01-01                               0
# 1        2020-01-02                               0
# 2        2020-01-03                               0
# 3        2020-01-04                               0
# 4        2020-01-05                               0
# ..              ...                             ...
# 297      2020-10-24                     1.59042e+06
# 298      2020-10-25                     1.59379e+06
# 299      2020-10-26                     1.60271e+06
# 300      2020-10-27                     1.60949e+06
# 301      2020-10-28                     1.60949e+06
#
# measure Florida.JHU_ConfirmedCases.missing Florida.JHU_ConfirmedDeaths.data  \
# 0                                     2900                                0
# 1                                     2900                                0
# 2                                     2900                                0
# 3                                     2900                                0
# 4                                     2900                                0
# ..                                     ...                              ...
# 297                                   2100                            33907
# 298                                   2100                            33919
# 299                                   2100                            33983
# 300                                   2100                            34066
# 301                                   2100                            34066
#
# measure Florida.JHU_ConfirmedDeaths.missing  \
# 0                                      2900
# 1                                      2900
# 2                                      2900
# 3                                      2900
# 4                                      2900
# ..                                      ...
# 297                                    2100
# 298                                    2100
# 299                                    2100
# 300                                    2100
# 301                                    2100
#
# measure Florida.JHU_ConfirmedRecoveries.data  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ..                                       ...
# 297                                        0
# 298                                        0
# 299                                        0
# 300                                        0
# 301                                        0
#
# measure Florida.JHU_ConfirmedRecoveries.missing
# 0                                          9900
# 1                                          9900
# 2                                          9900
# 3                                          9900
# 4                                          9900
# ..                                          ...
# 297                                        9900
# 298                                        9900
# 299                                        9900
# 300                                        9900
# 301                                        9900
#
# [302 rows x 7 columns]

# %%
ny = get_JHU('NewYork')
ny

# %%
path = '../../data/cases/'
ga.to_csv(path + 'GA_JHU_cases.csv', index=False)
ca.to_csv(path + 'CA_JHU_cases.csv', index=False)
fl.to_csv(path + 'FL_JHU_cases.csv', index=False)
ny.to_csv(path + 'NY_JHU_cases.csv', index=False)
